# %% [markdown]
# <a href="https://colab.research.google.com/github/anshurishabh/DSAI-practice/blob/main/Module_1_Pyhton_Programming_for_DS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = "Shivam"
age = 25
salary = 50000
print(name)
print(age)
print(salary)
# Out:
# Shivam
# 25
# 50000

# %% [markdown]
# Assigning Value To Variables
#
# 1. Basic Assignment

# %%
x = 5
y = 3.13
z = "Hi"
print(x)
print(y)
print(z)
# Out:
# 5
# 3.13
# Hi

# %% [markdown]
# Dyanamic Typing

# %%
y = 10
z= 3.14
x = "Shivam"
print(type(z))
print(type(y))
print(type(x))
# Out:
# <class 'float'>
# <class 'int'>
# <class 'str'>

# %% [markdown]
# 3. Assigning Same Values

# %%
A = B = C = 100
print(A , B , C)
# Out:
# 100 100 100

# %% [markdown]
# 4. Assigning Different Values

# %%
x, y, z = 1, 2.5, "python"
print(x, y, z)
# Out:
# 1 2.5 python

# %% [markdown]
# **Data Types**

# %% [markdown]
# Numeric Data Type
#
#  1.Integer

# %%
age = 25
print(type(age))
# Out:
# <class 'int'>

# %% [markdown]
# 2.Float

# %%
price = 99.99
print(type(price))
# Out:
# <class 'float'>

# %% [markdown]
# 3.Complex

# %%
x = 3 + 4j
print(x)
print(type(x))
# Out:
# (3+4j)
# <class 'complex'>

# %% [markdown]
# **Sequence Data Types**

# %% [markdown]
# 1.String

# %%
s = 'Welcome to BBD'
print(s)
print(type(s))
# Out:
# Welcome to BBD
# <class 'str'>

# %% [markdown]
# 2.List

# %%
a = [1, 2, 3]
print(a)
print(type(a))
b= ["BBD", "BBD", "BBD", 4, 5]
print(b)
print(type(b))
# Out:
# [1, 2, 3]
# <class 'list'>
# ['BBD', 'BBD', 'BBD', 4, 5]
# <class 'list'>

# %% [markdown]
# 3.Tuples

# %%
t1 = (1,)
print(type(t1))
t2 = ('BBD', 'BBD', 'BBD', 1, 2)
print(t2)
print(t2)
# Out:
# <class 'tuple'>
# ('BBD', 'BBD', 'BBD', 1, 2)
# ('BBD', 'BBD', 'BBD', 1, 2)

# %% [markdown]
# **Set Data Type**

# %% [markdown]
# Set

# %%
s1 = {"a", "a", "b", "c", "b"}
print(s1)
s2 = {"BBD", "FOR", "BBD"}
for i in s2:
  print(i)
# Out:
# {'b', 'c', 'a'}
# FOR
# BBD

# %% [markdown]
# **Dictionary Data Type**

# %%
d = {1: 'BBD',2: 'For', 3: 'BBD'}
print(d[1])
print(d.get(2))
# Out:
# BBD
# For

# %% [markdown]
# **Operators**

# %% [markdown]
# 1.Arithmetic Operator
#
# Arithmetic operators are used to perform basic mathematical operations like addition, subtraction, multiplication and division

# %%
a = 15
b = 4
print("Addition:", a+b)
print("Subtraction:", a-b)
print("Multiplication:", a*b)
print("Division:", a/b)
print("Floor Division:", a//b)
print("Modulus:", a%b)
print("Exponentiation:", a**b)
# Out:
# Addition: 19
# Subtraction: 11
# Multiplication: 60
# Division: 3.75
# Floor Division: 3
# Modulus: 3
# Exponentiation: 50625

# %% [markdown]
# **2.Comparision Operator**
#
# Cpmparision (or Relational) operators compares values. It either returns True or False according to the condition

# %%
a = 13
b = 33
print(a == b)
print(a != b)
print(a > b)
print(a < b)
print(a >= b)
print(a <= b)
# Out:
# False
# True
# False
# True
# False
# True
